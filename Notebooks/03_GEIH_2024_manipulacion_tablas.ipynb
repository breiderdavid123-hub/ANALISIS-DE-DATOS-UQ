# %% [markdown]
# Indicadores de Mercado Laboral Mediante la Metodologia DANE Exploracion y analisis descriptivos de los resultados de la GEIH 2024 (Diciembre)

# %% [markdown]
# Importando librerias

# %%
import pandas as pd
import numpy as np
from pathlib import Path
